# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib_inline as mlt

# %%
True_df=pd.read_csv('True.csv')
Fake_df=pd.read_csv('Fake.csv')

# %%
True_df['Label']=1
Fake_df['Label']=0

# %%
import os

output_path='.'
true_filename = 'True_df.csv'
fake_filename = 'Fake_df.csv'
True_Label=os.path.join(output_path,true_filename)
Fake_label=os.path.join(output_path,fake_filename)

True_df.to_csv(true_filename, index=False)
Fake_df.to_csv(fake_filename, index=False)
